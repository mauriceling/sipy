# %%
read excel surdata from data/survival_dataset.xlsx data

# %%
plot histogram dataframe data=surdata.biomarker_3m bins=10 kde=true

# %%
plot boxplot dataframe data=surdata x=stage y=biomarker_3m

# %%
plot scatterplot dataframe data=surdata x=biomarker_3m y=biomarker_6m
